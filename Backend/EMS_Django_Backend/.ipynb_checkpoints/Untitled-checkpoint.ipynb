# %%
import json

# %%
# with open('../../scrapers/georgiarcc.json', encoding='utf-8') as data_file:
#     json_data = json.loads(data_file.read())
#     for p in json_data:
#         print(p)

# %%
for line in open('georgiarcc.json', 'r'):
    tweets.append(json.loads(line))
# Out:
# {'0': [{'Hospital': 'Grady Health System', 'Nedocs': 'Busy', 'Status': ['Normal'], 'Updated': '02/22/2021 23:42:54'}, {'Hospital': 'WellStar - AMC', 'Nedocs': 'Overcrowded', 'Status': ['ICU/CCU Diversion'], 'Updated': '02/22/2021 23:35:28'}, {'Hospital': 'CHOA - Scottish Rite', 'Nedocs': 'Normal', 'Status': ['Normal'], 'Updated': '02/22/2021 23:28:23'}, {'Hospital': 'Emory - Decatur Hospital', 'Nedocs': 'Busy', 'Status': ['Normal'], 'Updated': '02/22/2021 23:05:18'}, {'Hospital': 'Southern Regional Medical Center', 'Nedocs': 'Overcrowded', 'Status': ['Psych Diversion'], 'Updated': '02/22/2021 22:56:55'}, {'Hospital': 'Piedmont - Atlanta Hospital', 'Nedocs': 'Overcrowded', 'Status': ['ER Saturation', 'ICU/CCU Diversion'], 'Updated': '02/22/2021 22:51:32'}, {'Hospital': 'Augusta University Medical Center', 'Nedocs': 'Overcrowded', 'Status': ['ICU/CCU Diversion', 'Medical Diversion', 'Psych Diversion'], 'Updated': '02/22/2021 22:46:29'}, {'Hospital': 'Piedmont - Fayette Hospital', 'Nedo
# ...
